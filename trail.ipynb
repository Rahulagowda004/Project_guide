# %%
import os

path = r"C:\vscode\Project_guide\Chat_With_Rahul\exceptions\custom_exception.py"

# %%
with open (path, 'r+') as f:
    content = f.read()
    print(len(content))
    f.write("hey")
# Out:
# 2194
